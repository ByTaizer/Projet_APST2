# %% [markdown]
# #### Roig Sébastien,

# %% [markdown]
# # Pendulum

# %% [markdown]
# ## Reinforce

# %%
import gymnasium as gym
import pygame
import numpy as np
import matplotlib.pyplot as plt
from collections import deque

# %%
env = gym.make("Pendulum-v1")
print('action space :')
print(env.action_space)
# print('left, down, right, up')
print('observation space:')
print(env.observation_space)
# print('a 4x4 grid of positions')
obs = env.reset()
observation, reward, done, truncated, info = env.step([1])
print(obs[0])
print(observation)
env.close()
# Out:
# action space :
# Box(-2.0, 2.0, (1,), float32)
# observation space:
# Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
# [-0.03101382  0.99951893  0.265829  ]
# [-0.0891736  0.9960161  1.1654682]

# %%
def train_opt_policy(N,eta = 0.001,gamma = 1, sig = 0.1):
    env = gym.make("Pendulum-v1")
    env.reset()
    teta = [0,0,0]
    history = np.zeros(N)

    for i in range(N):
            grads = []
            rewards = []
            x = env.reset()
            x = x[0]
            done = False
            truncated = False

            while not truncated:
                mu = np.dot(x,teta)
                if mu > 2:
                    mu = 2
                if mu < -2:
                    mu = -2
                action = np.random.normal(loc = mu, scale = sig) 
                if action > 2:
                    action = 2
                elif action < -2:
                    action = -2
                grad = np.dot((action-mu)/sig, x)
                
                x, reward, done, truncated, info = env.step([action])
                grads.append(grad)
                rewards.append(reward)

                
            history[i] = np.sum(rewards)
            T = len(grads)
            
            for t in range(T):
                G = 0
                for k in range(T-t):
                    G += gamma**(k-t-1)*rewards[k]
                teta += np.dot(eta*gamma**t*G, grads[t])

    env.close()
    return teta, history

# %%
N = 100
teta, history = train_opt_policy(N)
print(teta)
plt.plot(np.arange(N), history)
plt.xlabel('episode')
plt.ylabel('reward')
plt.title('evolution of reward per episode')
plt.show()
# Out:
# [-4010.77199693 -2284.73873931 -1966.82972902]

# %%
# %load question_5.py


sig = 1
env = gym.make("Pendulum-v1", render_mode = 'human')
x = env.reset()
x = x[0]
number_step = 0
truncated = False
while not truncated:
    number_step += 1 
    mu = np.dot(x,teta)
    action = np.random.normal(loc = mu, scale = sig)
    if action > 2:
        action = 2
    if action < -2:
        action = -2
    x, reward, done, truncated, info = env.step([action])

print(number_step)

env.close()
# Out:
# 200

# %%
env.close()
